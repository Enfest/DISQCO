# %%
import json
import os

with open('benchmark_results_COARSENING_POST_PROCESSED_direct_partitioning.json', 'r') as file:
    data = json.load(file)


sorted_results = {}

for element in data:

    num_qubits = element['num_qubits']
    network_type = element['network_type']
    num_partitions = element['num_partitions']
    level_limit = element['level_limit']
    initial_cost_no_grouping = element['initial_cost_no_grouping']
    initial_cost = element['initial_cost']
    final_cost = element['final_cost']
    iteration = element['iteration']
    time_taken = element['time_taken']
    seed = element['seed']


    key = (num_qubits, network_type, num_partitions)

    if key not in sorted_results:
        sorted_results[key] = []

    sorted_results[key].append({
        'initial_cost_no_grouping': initial_cost_no_grouping,
        'initial_cost': initial_cost,
        'final_cost': final_cost,
        'iteration': iteration,
        'time_taken': time_taken
    })

# %%
mean_results_sorted = {}

for key in sorted_results:

    num_qubits, network_type, num_partitions = key
    entry = sorted_results[key]
    valid_entries = [e for e in entry if e['final_cost'] is not None]
    if not valid_entries:
        continue  # Skip if there are no valid entries
    print(f"Valid entries for key {key}: {valid_entries}")
    mean_cost_init_ng = sum(e['initial_cost_no_grouping'] for e in valid_entries) / len(valid_entries)
    mean_cost_init = sum(e['initial_cost'] for e in valid_entries) / len(valid_entries)
    mean_cost_final = sum(e['final_cost'] for e in valid_entries) / len(valid_entries)
    if not valid_entries[0]['time_taken']:
        mean_time_taken = None
    else:
        mean_time_taken = sum(e['time_taken'] for e in valid_entries) / len(valid_entries)

    mean_results_sorted[key] = {
        'num_partitions': num_partitions,
        'mean_cost_init_ng': mean_cost_init_ng,
        'mean_cost_init': mean_cost_init,
        'mean_cost_final': mean_cost_final,
        'mean_time_taken': mean_time_taken
    }


# Now to write the results to separate .dat files based on the number of qubits and network type

for key, value in mean_results_sorted.items():
    num_qubits, network_type, num_partitions = key
    filename = f"direct_mean_results_{num_qubits}_{network_type}.dat"
    if not os.path.exists(filename):
        with open(filename, 'w') as file:
            file.write("num_partitions mean_cost_init_ng mean_cost_init mean_cost_final mean_time_taken\n")
    with open(filename, 'a') as file:
        file.write(f"{num_partitions} {value['mean_cost_init_ng']} {value['mean_cost_init']} {value['mean_cost_final']} {value['mean_time_taken']}\n")
# Out:
# Valid entries for key (128, 'linear', 4): [{'initial_cost_no_grouping': 5082, 'initial_cost': 3321, 'final_cost': 2259, 'iteration': 0, 'time_taken': 15.152664184570312}]
# Valid entries for key (128, 'linear', 8): [{'initial_cost_no_grouping': 10183, 'initial_cost': 6574, 'final_cost': 4926, 'iteration': 0, 'time_taken': 41.62704396247864}]
# Valid entries for key (128, 'linear', 16): [{'initial_cost_no_grouping': 19303, 'initial_cost': 12526, 'final_cost': 9764, 'iteration': 0, 'time_taken': 131.13145995140076}]
# Valid entries for key (128, 'linear', 32): [{'initial_cost_no_grouping': 34823, 'initial_cost': 22459, 'final_cost': 19863, 'iteration': 0, 'time_taken': 122.07402682304382}]
# Valid entries for key (128, 'linear', 64): [{'initial_cost_no_grouping': 58600, 'initial_cost': 37853, 'final_cost': 33093, 'iteration': 0, 'time_taken': 612.8565888404846}]
# Valid entries for key (128, 'grid', 4): [{'initial_cost_no_grouping': 4092, 'initial_cost': 2863, 'final_cost': 1839, 'iteration': 0, 'time_taken': 14.308506965637207}]
# Valid entries for key (128, 'grid', 8): [{'initial_cost_no_grouping': 6926, 'initial_cost': 5011, 'final_cost': 3366, 'iteration': 0, 'time_taken': 37.16909384727478}]
# Valid entries for key (128, 'grid', 16): [{'initial_cost_no_grouping': 9649, 'initial_cost': 7253, 'final_cost': 5068, 'iteration': 0, 'time_taken': 118.30611395835876}]
# Valid entries for key (128, 'grid', 32): [{'initial_cost_no_grouping': 13632, 'initial_cost': 10698, 'final_cost': 9041, 'iteration': 0, 'time_taken': 148.56019568443298}]
# Valid entries for key (128, 'grid', 64): [{'initial_cost_no_grouping': 18002, 'initial_cost': 14365, 'final_cost': 14365, 'iteration': 0, 'time_taken': None}]
# Valid entries for key (256, 'linear', 4): [{'initial_cost_no_grouping': 20417, 'initial_cost': 13085, 'final_cost': 9277, 'iteration': 0, 'time_taken': 76.38972973823547}]
# Valid entries for key (256, 'linear', 8): [{'initial_cost_no_grouping': 41807, 'initial_cost': 27034, 'final_cost': 21058, 'iteration': 0, 'time_taken': 290.63657808303833}]
# Valid entries for key (256, 'linear', 16): [{'initial_cost_no_grouping': 81351, 'initial_cost': 52473, 'final_cost': 43031, 'iteration': 0, 'time_taken': 1019.0357186794281}]
# Valid entries for key (256, 'linear', 32): [{'initial_cost_no_grouping': 153653, 'initial_cost': 99914, 'final_cost': 99914, 'iteration': 0, 'time_taken': None}]
# Valid entries for key (256, 'linear', 64): [{'initial_cost_no_grouping': 279362, 'initial_cost': 179892, 'final_cost': 179892, 'iteration': 0, 'time_taken': None}]
# Valid entries for key (256, 'grid', 4): [{'initial_cost_no_grouping': 16273, 'initial_cost': 11420, 'final_cost': 7529, 'iteration': 0, 'time_taken': 56.11299991607666}]
# Valid entries for key (256, 'grid', 8): [{'initial_cost_no_grouping': 27269, 'initial_cost': 19868, 'final_cost': 13985, 'iteration': 0, 'time_taken': 167.79936814308167}]
# Valid entries for key (256, 'grid', 16): [{'initial_cost_no_grouping': 40291, 'initial_cost': 30500, 'final_cost': 22059, 'iteration': 0, 'time_taken': 520.0317549705505}]
# Valid entries for key (256, 'grid', 32): [{'initial_cost_no_grouping': 56845, 'initial_cost': 44428, 'final_cost': 44428, 'iteration': 0, 'time_taken': None}]
# Valid entries for key (256, 'grid', 64): [{'initial_cost_no_grouping': 78151, 'initial_cost': 62518, 'final_cost': 62518, 'iteration': 0, 'time_taken': None}]
# Valid entries for key (512, 'linear', 4): [{'initial_cost_no_grouping': 81463, 'initial_cost': 51969, 'final_cost': 38874, 'iteration': 0, 'time_taken': 705.4339070320129}]
# Valid entries for key (512, 'grid', 4): [{'initial_cost_no_grouping': 65300, 'initial_cost': 45867, 'final_cost': 31173, 'iteration': 0, 'time_taken': 274.24968791007996}]
